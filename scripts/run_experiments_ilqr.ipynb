# %%
from lander.experiments import *

# %%
ilqr_runners = run_ilqr_experiments(50)
# Out:
# 100%|██████████| 50/50 [06:21<00:00,  7.62s/it]

# %%
save_runner_metrics(ilqr_runners, "ilqr_results.json")

# %%
print("ILQR Stats")
out = calc_stats(ilqr_runners)
# Out:
# ILQR Stats
# Averages
# {'inside_helipad': 1.0, 'land_upright': 0.8367346938775511, 'land_slowly': 0.0, 'touched_ground': 1.0, 'out_of_bounds': 0.0, 'num_steps': 87.79591836734694, 'end_state': array([ 2.36676625e-01,  7.41419243e+00,  1.50039122e+01, -1.06723368e+02,
#         1.72109302e-02,  6.98762605e-02]), 'total_reward': 71.04081632653062, 'total_fuel': 3000.1638860190915, 'ilqr_final_cost': 400.73993175727503}
